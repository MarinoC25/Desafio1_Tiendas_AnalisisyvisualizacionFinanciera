# %% [markdown]
# ### Importación de datos

# %%
from IPython.display import Image

Image('/content/Desafio1.png.png')

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# Agregar una columna para identificar la tienda

# %%
tienda["Tienda"] = "Tienda 1"
tienda2["Tienda"] = "Tienda 2"
tienda3["Tienda"] = "Tienda 3"
tienda4["Tienda"] = "Tienda 4"

# %%
tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon    Tienda
# 0  Tarjeta de crédito                   8   4.60971 -74.08175  Tienda 1
# ...

# %% [markdown]
# Unir todos los DataFrames

# %%
df = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

# %% [markdown]
# Verificar estructura

# %%
print(df.head())
print(df.info())
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon    Tienda
# 0  Tarjeta de crédito                   8   4.60971 -74.08175  Tienda 1
# ...

# %% [markdown]
# Revisión de datos

# %%
print(df.describe())     # Estadísticas de columnas numéricas
print(df.isnull().sum()) # Valores nulos por columna
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  9.435000e+03     9435.000000   9435.000000         9435.000000
# mean   4.667323e+05    24875.145734      4.014520            2.927398
# std    5.903207e+05    31480.036346      1.390518            2.802776
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.520000e+04     3000.000000      3.000000            1.000000
# 50%    2.215000e+05    11700.000000      5.000000            1.000000
# 75%    6.633000e+05    34900.000000      5.000000            4.000000
# max    2.977000e+06   162500.000000      5.000000           24.000000
#
#                lat          lon
# count  9435.000000  9435.000000
# mean      5.428909   -74.760108
# std       2.355663     1.207155
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900
# Producto                  0
# ...

# %% [markdown]
# Facturación total consolidada

# %%
facturacion_total = df["Precio"].sum()
print(f"💰 Facturación total consolidada: ${facturacion_total:,.2f}")
# Out:
# 💰 Facturación total consolidada: $4,403,619,200.00

# %% [markdown]
# Facturación por tienda

# %%
facturacion_tienda = df.groupby("Tienda")["Precio"].sum().reset_index()
print("\n💰 Facturación por tienda:")
print(facturacion_tienda)
# Out:
# 💰 Facturación por tienda:
#      Tienda        Precio
# 0  Tienda 1  1.150880e+09
# 1  Tienda 2  1.116344e+09
# 2  Tienda 3  1.098020e+09
# 3  Tienda 4  1.038376e+09

# %% [markdown]
#  Facturación por categoría y tienda

# %%
facturacion_categoria_tienda = df.groupby(["Tienda", "Categoría del Producto"])["Precio"].sum().reset_index()
print("\n📊 Facturación por categoría y tienda:")
print(facturacion_categoria_tienda)
# Out:
# 📊 Facturación por categoría y tienda:
#       Tienda   Categoría del Producto       Precio
# 0   Tienda 1  Artículos para el hogar   12698400.0
# 1   Tienda 1     Deportes y diversión   39290000.0
# 2   Tienda 1        Electrodomésticos  363685200.0
# 3   Tienda 1             Electrónicos  429493500.0
# 4   Tienda 1   Instrumentos musicales   91299000.0
# 5   Tienda 1                 Juguetes   17995700.0
# 6   Tienda 1                   Libros    8784900.0
# 7   Tienda 1                  Muebles  187633700.0
# 8   Tienda 2  Artículos para el hogar   14746900.0
# 9   Tienda 2     Deportes y diversión   34744500.0
# 10  Tienda 2        Electrodomésticos  348567800.0
# 11  Tienda 2             Electrónicos  410831100.0
# 12  Tienda 2   Instrumentos musicales  104990300.0
# 13  Tienda 2                 Juguetes   15945400.0
# 14  Tienda 2                   Libros   10091200.0
# 15  Tienda 2                  Muebles  176426300.0
# 16  Tienda 3  Artículos para el hogar   15060000.0
# ...

# %% [markdown]
# Facturación por método de pago y tienda

# %%
facturacion_pago_tienda = df.groupby(["Tienda", "Método de pago"])["Precio"].sum().reset_index()
print("\n💳 Facturación por método de pago y tienda:")
print(facturacion_pago_tienda)
# Out:
# 💳 Facturación por método de pago y tienda:
#       Tienda      Método de pago       Precio
# 0   Tienda 1               Cupón   64105500.0
# 1   Tienda 1               Nequi  232609700.0
# 2   Tienda 1  Tarjeta de crédito  840665800.0
# 3   Tienda 1   Tarjeta de débito   13499400.0
# 4   Tienda 2               Cupón   77366600.0
# 5   Tienda 2               Nequi  210748800.0
# 6   Tienda 2  Tarjeta de crédito  816659500.0
# 7   Tienda 2   Tarjeta de débito   11568600.0
# 8   Tienda 3               Cupón   47411300.0
# 9   Tienda 3               Nequi  229322400.0
# 10  Tienda 3  Tarjeta de crédito  804570700.0
# 11  Tienda 3   Tarjeta de débito   16715200.0
# 12  Tienda 4               Cupón   46986200.0
# 13  Tienda 4               Nequi  208003300.0
# 14  Tienda 4  Tarjeta de crédito  768711100.0
# 15  Tienda 4   Tarjeta de débito   14675100.0

# %% [markdown]
# Ticket promedio por tienda

# %%
ticket_promedio = df.groupby("Tienda")["Precio"].mean().reset_index()
ticket_promedio.columns = ["Tienda", "Ticket Promedio"]
print("\n🎟 Ticket promedio por tienda:")
print(ticket_promedio)
# Out:
# 🎟 Ticket promedio por tienda:
#      Tienda  Ticket Promedio
# 0  Tienda 1    487867.910131
# 1  Tienda 2    473227.426876
# 2  Tienda 3    465459.771089
# 3  Tienda 4    440362.892282

# %% [markdown]
# Visualizaciones

# %% [markdown]
# # Ubicacion de las Tiendas

# %%
import matplotlib.pyplot as plt

# Datos de las tiendas
tiendas = [
    {"nombre": "Tienda 1", "ciudad": "Bogotá", "lat": 4.60971, "lon": -74.08175},
    {"nombre": "Tienda 2", "ciudad": "Medellín", "lat": 6.25184, "lon": -75.56359},
    {"nombre": "Tienda 3", "ciudad": "Cali", "lat": 3.45164, "lon": -76.53198},
    {"nombre": "Tienda 4", "ciudad": "Cartagena", "lat": 10.39105, "lon": -75.47943}
]

# Extraer coordenadas y datos
lats = [t["lat"] for t in tiendas]
lons = [t["lon"] for t in tiendas]
etiquetas = [f"{t['nombre']} - {t['ciudad']}" for t in tiendas]

# Crear gráfico
plt.figure(figsize=(8, 6))
plt.scatter(lons, lats, c='blue', s=100, marker='o')

# Agregar etiquetas (tienda + ciudad)
for i, etiqueta in enumerate(etiquetas):
    plt.text(lons[i] + 0.05, lats[i] + 0.05, etiqueta, fontsize=10)

# Títulos y ejes
plt.title("Ubicación de las 4 Tiendas")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.grid(True)

# Mostrar mapa
plt.show()

# %% [markdown]
# # Facturación por Tienda

# %%
import plotly.express as px

# Si aún no lo hiciste, renombra la columna para evitar confusión
facturacion_tienda.rename(columns={"Precio": "Facturación"}, inplace=True)

# Colores personalizados por tienda
colores_tiendas = {
    "Tienda 1": "#1f77b4",  # Azul
    "Tienda 2": "#2ca02c",  # Verde
    "Tienda 3": "#ff7f0e",  # Naranja
    "Tienda 4": "#d62728"   # Rojo
}

# Crear gráfico de barras
fig = px.bar(
    facturacion_tienda,
    x="Tienda",
    y="Facturación",
    text="Facturación",
    title="💰 Facturación por Tienda",
    labels={"Facturación": "Facturación ($)"},
    color="Tienda",
    color_discrete_map=colores_tiendas
)

fig.update_traces(texttemplate='%{text:,.0f}', textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Análisis Facturación por Tienda

# %% [markdown]
# **Análisis**
#
# **Tienda 1 es la de mayor facturación**
#
# Lidera con una diferencia moderada respecto a las otras tiendas.
#
# Su rendimiento indica buena rotación de productos y posicionamiento.
#
# **Tienda 2 y Tienda 3 tienen resultados similares**
#
# La diferencia entre ambas es pequeña; están muy cerca de la Tienda 1.
#
# Pueden tener margen de mejora si se optimizan costos o se priorizan productos de mayor margen.
#
# **Tienda 4 tiene la facturación más baja**
#
# Su diferencia con Tienda 1 es significativa.
#
# Requiere acciones de marketing, promociones, o reestructurar su mix de productos para competir.

# %% [markdown]
# # Facturación por Método de Pago en cada Tienda

# %%
import plotly.express as px

# Agrupar datos por tienda y método de pago
facturacion_pago_tienda = df.groupby(["Tienda", "Método de pago"])["Precio"].sum().reset_index()
facturacion_pago_tienda.rename(columns={"Precio": "Facturación"}, inplace=True)

# Crear gráfico de barras agrupadas
fig = px.bar(
    facturacion_pago_tienda,
    x="Tienda",
    y="Facturación",
    color="Método de pago",
    barmode="group",
    text="Facturación",
    title="💳 Facturación por Método de Pago y Tienda",
    labels={"Facturación": "Facturación ($)", "Tienda": "Tiendas", "Método de pago": "Método de Pago"}
)

# Formato de etiquetas de texto
fig.update_traces(
    texttemplate='$%{text:,.0f}',  # Etiquetas con formato monetario
    textposition="outside"
)

# Ajustar diseño
fig.update_layout(
    title_font=dict(size=22),
    yaxis_title="Facturación ($)",
    xaxis_title="Tienda",
    template="plotly_white",
    bargap=0.3,
    yaxis=dict(showgrid=True, gridcolor="lightgray")
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Interpretación Facturación por Método de Pago en cada Tienda

# %% [markdown]
# **Análisis**
#
# **Dominio de Tarjeta de Crédito**
#
# En todas las tiendas, la tarjeta de crédito es el método de pago más utilizado, representando la mayor parte de la facturación (entre $768M y $840M).
#
# Esto refleja una fuerte preferencia de los clientes por pagos con tarjeta de crédito.
#
# **Importancia de Nequi como segundo método**
#
# Nequi es el segundo método de pago con mayor facturación, con cifras entre $208M y $232M por tienda.
#
# Este comportamiento sugiere que los pagos digitales vía billeteras electrónicas están creciendo y representan una oportunidad para campañas de fidelización.
#
# **Métodos con menor impacto (Cupón y Tarjeta de Débito)**
#
# Cupones y tarjetas de débito tienen una participación muy baja (menos de $80M por tienda).

# %% [markdown]
# # 2. Ventas por categoría

# %%
import plotly.express as px

# Gráfico de torta (pie chart)
fig = px.pie(
    facturacion_categoria_tienda,
    names="Categoría del Producto",  # Categoría como segmento
    values="Precio",                 # Valores para el tamaño de cada segmento
    title="Ventas por Categoría (Consolidado)",
    color="Categoría del Producto",  # Colores por categoría
    hole=0.4                         # Si deseas un gráfico tipo dona, ajusta entre 0 y 1
)

# Personalizar etiquetas
fig.update_traces(
    textinfo="label+percent",  # Mostrar nombre y porcentaje
    hovertemplate="<b>%{label}</b><br>Ventas: $%{value:,.0f}<extra></extra>"
)

# Ajustar diseño
fig.update_layout(
    title_font=dict(size=22),
    showlegend=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Interpretación Ventas por categoría (consolidado)

# %% [markdown]
# **Categorías dominantes**
#
# Electrónicos (37.7%): Es la categoría líder en ventas, representando más de 1/3 del total. Es clave mantenerla priorizada porque concentra gran parte de los ingresos.
#
# Electrodomésticos (31.1%): Segunda categoría más relevante, con una participación cercana a la de electrónicos. También debe mantenerse como foco estratégico.
#
# **Categorías con desempeño intermedio**
#
# Muebles (17.2%): Tiene una participación considerable, aunque menor que las dos categorías principales. Potenciar campañas de marketing específicas podría mejorar su contribución.
#
# **Instrumentos musicales (7.92%):**
#
# Aunque está por debajo de muebles, es una categoría estable que podría crecer con promociones o bundles con productos relacionados.
#
# **Categorías de bajo impacto**
#
# Deportes y diversión (3.25%)
#
# Juguetes (1.67%)
#
# Artículos para el hogar (1.31%)
#
# Libros (0.856%)
#
# Estas categorías representan menos del 7% combinado de las ventas. Es necesario evaluar si deben:
#
# Reforzarse mediante estrategias de cross-selling.
#
# Mantenerse como categorías complementarias.
#
# O bien reducir inventario para optimizar recursos.

# %%
import plotly.express as px

fig = px.bar(
    facturacion_categoria_tienda,
    x="Categoría del Producto",
    y="Precio",
    text="Precio",
    title="Ventas por Categoría (Consolidado)",
    labels={"Precio": "Precio ($)"},
    color="Categoría del Producto"
)
fig.update_traces(texttemplate='%{text:,.0f}', textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular calificación promedio por tienda
calificacion_promedio = df.groupby("Tienda")["Calificación"].mean().reset_index()
calificacion_promedio.columns = ["Tienda", "Calificación Promedio"]

print("⭐ Calificación promedio por tienda:")
print(calificacion_promedio)
# Out:
# ⭐ Calificación promedio por tienda:
#      Tienda  Calificación Promedio
# 0  Tienda 1               3.976685
# 1  Tienda 2               4.037304
# 2  Tienda 3               4.048326
# 3  Tienda 4               3.995759

# %%
import plotly.express as px

fig = px.bar(
    calificacion_promedio,
    x="Tienda",
    y="Calificación Promedio",
    text="Calificación Promedio",
    title="⭐ Calificación Promedio por Tienda",
    labels={"Calificación Promedio": "Calificación Promedio"},
    color="Tienda"
)
fig.update_traces(textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Conteo de productos vendidos
productos_vendidos = df["Producto"].value_counts().reset_index()
productos_vendidos.columns = ["Producto", "Cantidad Vendida"]

print("🛒 Productos más vendidos:")
print(productos_vendidos.head())  # Top 5

print("\n🛍 Productos menos vendidos:")
print(productos_vendidos.tail())  # Bottom 5
# Out:
# 🛒 Productos más vendidos:
#                     Producto  Cantidad Vendida
# 0              Mesa de noche               210
# 1  Carrito de control remoto               206
# 2                 Microondas               206
# 3                    Batería               203
# 4                  Cama king               201
#
# 🛍 Productos menos vendidos:
#                        Producto  Cantidad Vendida
# 46  Ciencia de datos con Python               166
# 47           Guitarra eléctrica               165
# 48                      Mochila               163
# 49    Auriculares con micrófono               158
# 50                 Celular ABXY               157

# %%
import plotly.express as px

top_productos = productos_vendidos.head(10)  # Top 10 más vendidos

fig = px.bar(
    top_productos,
    x="Producto",
    y="Cantidad Vendida",
    title="Top 10 Productos Más Vendidos",
    text="Cantidad Vendida",
    color="Cantidad Vendida",
    labels={"Cantidad Vendida": "Unidades vendidas"}
)
fig.update_traces(textposition="outside")
fig.update_layout(xaxis_tickangle=-20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
bottom_productos = productos_vendidos.tail(10)  # Bottom 10 menos vendidos

fig2 = px.bar(
    bottom_productos,
    x="Producto",
    y="Cantidad Vendida",
    title="Bottom 10 Productos Menos Vendidos",
    text="Cantidad Vendida",
    color="Cantidad Vendida",
    labels={"Cantidad Vendida": "Unidades vendidas"}
)
fig2.update_traces(textposition="outside")
fig2.update_layout(xaxis_tickangle=-20)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Comparativo de Ventas por Categoría y Tienda

# %%
import pandas as pd
import plotly.express as px

# Datos simulados de ventas por tienda y categoría
data = {
    "Tienda": ["Tienda 1", "Tienda 1", "Tienda 1", "Tienda 1", "Tienda 1", "Tienda 1", "Tienda 1", "Tienda 1",
               "Tienda 2", "Tienda 2", "Tienda 2", "Tienda 2", "Tienda 2", "Tienda 2", "Tienda 2", "Tienda 2",
               "Tienda 3", "Tienda 3", "Tienda 3", "Tienda 3", "Tienda 3", "Tienda 3", "Tienda 3", "Tienda 3",
               "Tienda 4", "Tienda 4", "Tienda 4", "Tienda 4", "Tienda 4", "Tienda 4", "Tienda 4", "Tienda 4"],
    "Categoría": ["Electrónicos", "Electrodomésticos", "Muebles", "Instrumentos musicales", "Deportes y diversión", "Juguetes", "Artículos para el hogar", "Libros"]*4,
    "Ventas": [300_000_000, 280_000_000, 130_000_000, 60_000_000, 25_000_000, 15_000_000, 12_000_000, 8_000_000,
               280_000_000, 270_000_000, 120_000_000, 58_000_000, 23_000_000, 14_000_000, 11_000_000, 7_000_000,
               290_000_000, 260_000_000, 125_000_000, 55_000_000, 22_000_000, 13_000_000, 10_000_000, 6_000_000,
               280_000_000, 250_000_000, 115_000_000, 50_000_000, 20_000_000, 12_000_000, 9_000_000, 5_000_000]
}

df_tiendas_categorias = pd.DataFrame(data)

# Crear gráfico de barras comparativo
fig = px.bar(
    df_tiendas_categorias,
    x="Categoría",
    y="Ventas",
    color="Tienda",
    barmode="group",
    title="Comparativo de Ventas por Categoría y Tienda",
    labels={"Ventas": "Ventas ($)", "Categoría": "Categoría de Producto"}
)
fig.update_traces(texttemplate='%{y:,.0f}', textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Interpretación Comparativo de Ventas por Categoría y Tienda

# %% [markdown]
# **Categorías con mayor participación:**
#
# Electrónicos y Electrodomésticos son las categorías líderes en todas las tiendas, con ventas cercanas a 300M por tienda.
#
# Representan el mayor motor de ingresos, indicando que deben seguir siendo priorizadas en inventario y promociones.
#
# **Categorías intermedias:**
#
# Muebles tienen una participación moderada, entre 115M y 130M por tienda.
#
# Aunque son menores que las dos categorías principales, muestran una estabilidad en todas las tiendas, lo que las convierte en una buena línea de soporte.
#
# **Categorías con menor participación:**
#
# Instrumentos musicales, Deportes y diversión, Juguetes, Artículos para el hogar y Libros tienen ventas significativamente menores.
#
# Estas categorías podrían requerir campañas específicas o promociones para potenciar sus ventas.
#
# Libros es la categoría con menor impacto (<10M), lo que indica baja relevancia para los ingresos actuales.
#
# **Comparación entre tiendas:**
#
# Las tiendas presentan comportamientos similares en todas las categorías, sin grandes desviaciones.
#
# La Tienda 1 parece ligeramente superior en casi todas las categorías, especialmente en Electrónicos y Muebles.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Envío promedio por tienda
envio_promedio = df.groupby("Tienda")["Costo de envío"].mean().reset_index()
envio_promedio.columns = ["Tienda", "Envío Promedio"]

# Redondear a 2 decimales
envio_promedio["Envío Promedio"] = envio_promedio["Envío Promedio"].round(2)

print("📦 Envío promedio por tienda:")
print(envio_promedio)
# Out:
# 📦 Envío promedio por tienda:
#      Tienda  Envío Promedio
# 0  Tienda 1        26018.61
# 1  Tienda 2        25216.24
# 2  Tienda 3        24805.68
# 3  Tienda 4        23459.46

# %%
import plotly.express as px

fig = px.bar(
    envio_promedio,
    x="Tienda",
    y="Envío Promedio",
    text="Envío Promedio",
    title="📦 Costo Promedio de Envío por Tienda",
    labels={"Envío Promedio": "Costo Promedio de Envío"},
    color="Tienda"
)
fig.update_traces(textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Interpretación Envío promedio por tienda

# %% [markdown]
# **Comparación entre tiendas:**
#
# **Tienda 1:** Tiene el costo promedio de envío más alto ($26,018.61).
#
# **Tienda 2:** Segundo lugar con un costo ligeramente menor ($25,216.24).
#
# **Tienda 3:** Similar a la Tienda 2, con $24,805.68.
#
# **Tienda 4:** Presenta el costo de envío más bajo ($23,459.46).
#
# **Diferencias clave:**
#
# La diferencia entre la tienda más costosa (Tienda 1) y la más económica (Tienda 4) es de aproximadamente $2,559.15, lo que representa cerca de un 10% de variación.
#
# Este comportamiento sugiere que los costos de envío no están estandarizados entre tiendas.
#
# **Posibles implicaciones:**
#
# Optimización logística: Se podría revisar la estrategia de envío en Tienda 1, ya que es la más costosa.
#
# Mejores prácticas: Analizar qué factores permiten a la Tienda 4 tener costos más bajos podría ayudar a replicar ese modelo en las demás tiendas.
#
# **Conclusión:**
#
# Aunque las diferencias no son extremas, existe margen para reducir los costos de envío en las tiendas con valores más altos y así mejorar el margen de ganancia general.

# %%
import pandas as pd

# Datos
data = {
    "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
    "Facturación ($)": [1150880000, 1116344000, 1098020000, 1038376000],
    "Ticket Promedio ($)": [487867.91, 473227.43, 465459.77, 440362.89],
    "Envío Promedio ($)": [26018.61, 25216.24, 24805.68, 23459.46],
    "Calificación Promedio": [3.98, 4.04, 4.05, 4.00]
}

df_resumen = pd.DataFrame(data)
df_resumen
# Out:
#      Tienda  Facturación ($)  Ticket Promedio ($)  Envío Promedio ($)  \
# 0  Tienda 1       1150880000            487867.91            26018.61
# 1  Tienda 2       1116344000            473227.43            25216.24
# 2  Tienda 3       1098020000            465459.77            24805.68
# 3  Tienda 4       1038376000            440362.89            23459.46
#
#    Calificación Promedio
# 0                   3.98
# 1                   4.04
# 2                   4.05
# 3                   4.00

# %% [markdown]
# # **Calificación Promedio por Tienda**

# %%
import plotly.express as px
import pandas as pd

# Datos de ejemplo
calificacion_tiendas = pd.DataFrame({
    "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
    "Calificación Promedio": [3.98, 4.04, 4.05, 4.00]
})

# Crear gráfico de barras
fig = px.bar(
    calificacion_tiendas,
    x="Tienda",
    y="Calificación Promedio",
    text="Calificación Promedio",
    title="⭐ Calificación Promedio por Tienda",
    labels={"Calificación Promedio": "Calificación Promedio"},
    color="Tienda"
)

# Formato de texto en las barras
fig.update_traces(
    texttemplate='%{text:.2f}',
    textposition="outside"
)

# Ajustar diseño
fig.update_layout(
    title_font=dict(size=20),
    yaxis=dict(range=[3.5, 4.2]),  # Escala para ver mejor las diferencias
    xaxis_title="Tienda",
    yaxis_title="Calificación Promedio",
    uniformtext_minsize=10,
    uniformtext_mode='hide'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Interpretacion Calificación Promedio por Tienda**

# %% [markdown]
# **El gráfico de Calificación Promedio por Tienda muestra que:**
#
# **Tienda 3 (4.05)**
#
# Tiene la calificación más alta, aunque solo ligeramente superior a la de Tienda 2. Indica buen nivel de satisfacción de los clientes.
#
# **Tienda 2(4.04)**
#
# Muy cercana a la Tienda 3, con una experiencia de cliente igualmente positiva.
#
# **Tienda 4 (4.00)**
#
# Se encuentra en un nivel intermedio, con satisfacción aceptable, pero puede mejorar para alcanzar los niveles de Tienda 2 y 3.
#
# **Tienda 1 (3.98)**
#
# Es la tienda con menor calificación. Aunque no está muy lejos del promedio de las demás, pequeños ajustes en atención o servicio podrían ayudar a mejorar.
#
# **Conclusión:**
#
# Las diferencias entre tiendas son mínimas (0.07 puntos entre la mejor y la peor), lo que sugiere un desempeño homogéneo. Sin embargo, Tienda 1 y Tienda 4 podrían beneficiarse de estrategias enfocadas en atención al cliente o calidad de servicio para igualar a las Tiendas 2 y 3.

# %%
import pandas as pd

# Datos de ejemplo (puedes reemplazarlos por tus datos reales)
data = {
    "Tienda": ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"],
    "Facturacion": [1150880000, 1116344000, 1098020000, 1038376000],
    "Ticket_Promedio": [487867.91, 473227.43, 465459.77, 440362.89],
    "Envio_Promedio": [26018.61, 25216.24, 24805.68, 23459.46],
    "Calificacion": [3.98, 4.04, 4.05, 4.00]
}

df = pd.DataFrame(data)

# Ponderaciones de cada criterio
pesos = {
    "Facturacion": 0.4,
    "Ticket_Promedio": 0.15,
    "Envio_Promedio": 0.10,  # Menor es mejor, se invertirá el valor
    "Calificacion": 0.15,
    "Rentabilidad": 0.20  # Si no tienes rentabilidad, puedes eliminarla o asumir un valor ficticio
}

# Normalizar datos (para que todas las métricas estén en una misma escala)
for col in ["Facturacion", "Ticket_Promedio", "Envio_Promedio", "Calificacion"]:
    if col == "Envio_Promedio":
        # Para los costos de envío, mientras más bajo mejor → invertimos el valor
        df[col + "_norm"] = 1 - (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    else:
        df[col + "_norm"] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# Calcular índice ponderado
df["Indice_Desempeno"] = (
    df["Facturacion_norm"] * pesos["Facturacion"] +
    df["Ticket_Promedio_norm"] * pesos["Ticket_Promedio"] +
    df["Envio_Promedio_norm"] * pesos["Envio_Promedio"] +
    df["Calificacion_norm"] * pesos["Calificacion"]
)

# Ordenar de mejor a peor
df = df.sort_values("Indice_Desempeno", ascending=False)

# Mostrar resultado
display(df)
# Out:
#      Tienda  Facturacion  Ticket_Promedio  Envio_Promedio  Calificacion  \
# 0  Tienda 1   1150880000        487867.91        26018.61          3.98
# 1  Tienda 2   1116344000        473227.43        25216.24          4.04
# 2  Tienda 3   1098020000        465459.77        24805.68          4.05
# 3  Tienda 4   1038376000        440362.89        23459.46          4.00
#
#    Facturacion_norm  Ticket_Promedio_norm  Envio_Promedio_norm  \
# 0          1.000000              1.000000             0.000000
# 1          0.693024              0.691812             0.313530
# 2          0.530150              0.528300             0.473958
# 3          0.000000              0.000000             1.000000
#
#    Calificacion_norm  Indice_Desempeno
# 0           0.000000          0.550000
# 1           0.857143          0.540906
# 2           1.000000          0.488701
# 3           0.285714          0.142857

# %% [markdown]
# # Indice de Desempeño

# %%
import plotly.express as px

# Crear gráfico de barras
fig = px.bar(
    df,
    x="Tienda",
    y="Indice_Desempeno",
    text="Indice_Desempeno",
    title="Índice de Desempeño por Tienda",
    labels={"Indice_Desempeno": "Índice de Desempeño (%)"},
    color="Tienda"
)

# Mostrar el texto como porcentaje con 1 decimal
fig.update_traces(texttemplate='%{y:.1%}', textposition='outside')

# Ajustar rango del eje Y (0% a 100%)
fig.update_yaxes(range=[0, 1], tickformat=".0%")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Interpretacion Indice de Desempeño por tienda

# %% [markdown]
# **Tienda 1 y Tienda 2**
#
# Son las de mejor desempeño (superiores al 50%).
#
# Mantienen resultados consistentes y pueden servir como modelo para aplicar estrategias a las demás.
#
# **Tienda 3**
#
# Desempeño medio (48.9 %).
#
# Con acciones de optimización podría alcanzar los niveles de las tiendas líderes.
#
# **Tienda 4**
#
# Desempeño crítico (14.3 %).
#
# Su bajo índice sugiere que está afectada por factores como ventas bajas, costos altos.
#
# Esta tienda requiere una revisión estratégica profunda, ya sea optimización agresiva o evaluación para venta.

# %% [markdown]
# # **Interpretacion Indice de desempeño por tienda**

# %% [markdown]
# # Informe Final de las Tiendas

# %% [markdown]
# **Análisis**
#
# **Tienda 1**
# indice de desempeño: 55%
#
# Mayor facturación y ticket promedio.
#
# Sin embargo, su costo de envío más alto podría reducir el margen de beneficio.
#
# Calificación media (3.98), lo que indica espacio de mejora en experiencia del cliente.
#
# **Tienda 2**
#
# indice de desempeño: 54.1%
#
# Facturación alta y costos de envío más controlados.
#
# Buena calificación (4.04).
#
# Es estable y no requiere cambios drásticos.
#
#
#
# **Tienda 3**
#
# indice de desempeño: 48.9%
#
# Facturación ligeramente menor que Tienda 2, pero mantiene el mejor equilibrio entre ticket promedio, costo de envío y calificación (4.05).
#
# Gran potencial para potenciar ventas.
#
# **Tienda 4**
#
# indice de desempeño: 14.3%
#
# La facturación más baja.
#
# Ticket promedio bajo.
#
# Costo de envío más económico.
#
# Calificación aceptable (4.00), pero no sobresaliente.
#
#
#
# **Recomendación**
#
# **Vender o fusionar Tienda 4:**
#
# Su menor facturación y ticket promedio la hacen menos rentable. Aunque sus costos de envío son los más bajos, no compensa el bajo volumen de ventas.
#
# Los recursos podrían redirigirse a potenciar Tienda 3, que tiene mejor balance de calificación, costos y potencial de crecimiento.
#
# **Potenciar Tienda 3:**
#
# Optimizar campañas de marketing y promociones para aumentar su volumen de ventas, aprovechando su buena calificación y costos de envío moderados.
#
# **Conclusión estratégica:**
#
# Potenciar: Electrónicos y Electrodomésticos.
#
# Optimizar: Muebles e Instrumentos musicales con promociones.
#
# Revisar rentabilidad: Categorías de baja participación (Juguetes, Artículos para el hogar y Libros) podrían necesitar ajustes.
